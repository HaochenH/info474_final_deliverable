# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./weather_data/PHX.csv')
df.head()
# Out:
#        date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0  2014-7-1                98               86              109
# 1  2014-7-2                98               86              109
# 2  2014-7-3                94               79              108
# 3  2014-7-4                90               81               98
# 4  2014-7-5                94               84              103
#
#    average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                82               107               65              115
# 1                82               107               65              118
# 2                82               107               64              117
# 3                83               107               63              118
# 4                83               107               63              116
#
#    record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 0                  1927                  1990                  0.00
# 1                  1911                  2011                  0.00
# 2                  1916                  1907                  0.00
# 3                  1912                  1989                  0.00
# 4                  1912                  1983                  0.01
#
#    average_precipitation  record_precipitation
# 0                   0.02                  2.68
# 1                   0.01                  2.81
# 2                   0.02                  0.22
# 3                   0.02                  0.22
# 4                   0.02                  0.18

# %%
df.describe()
# Out:
#        actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# count        365.000000       365.000000       365.000000        365.000000
# mean          77.320548        65.761644        88.389041         63.501370
# std           14.055375        14.095072        14.506228         14.070588
# min           41.000000        31.000000        46.000000         44.000000
# 25%           66.000000        54.000000        77.000000         50.000000
# 50%           77.000000        65.000000        89.000000         62.000000
# 75%           90.000000        79.000000       101.000000         78.000000
# max          105.000000        94.000000       116.000000         84.000000
#
#        average_max_temp  record_min_temp  record_max_temp  \
# count        365.000000       365.000000       365.000000
# mean          86.717808        43.016438       100.010959
# std           14.704034        14.946783        12.650626
# min           65.000000        16.000000        77.000000
# 25%           72.000000        30.000000        88.000000
# 50%           87.000000        40.000000       102.000000
# 75%          102.000000        56.000000       112.000000
# max          107.000000        70.000000       122.000000
#
#        record_min_temp_year  record_max_temp_year  actual_precipitation  \
# count            365.000000            365.000000            365.000000
# mean            1934.356164           1976.279452              0.027726
# std               24.477041             29.460417              0.205119
# min             1895.000000           1896.000000              0.000000
# 25%             1913.000000           1956.000000              0.000000
# 50%             1929.000000           1985.000000              0.000000
# 75%             1961.000000           2000.000000              0.000000
# max             1990.000000           2015.000000              3.290000
#
#        average_precipitation  record_precipitation
# count             365.000000            365.000000
# mean                0.022000              0.770466
# std                 0.012649              0.537395
# min                 0.000000              0.010000
# 25%                 0.010000              0.360000
# 50%                 0.020000              0.710000
# 75%                 0.030000              1.050000
# max                 0.050000              3.290000

# %%
# year with highest average temperature
df.groupby('date').mean()['actual_max_temp'].idxmax()
# Out:
# '2014-7-24'
